# %% [markdown]
# # Create the 100000 entry dataset and save it to a CSV file to be used on the main file

# %%
import pandas as pd

# %% [markdown]
# ## Fortosh tou dataset

# %%
us_accidents_OG_dataset = pd.read_csv('US_Accidents_March23.csv')

# %% [markdown]
# ## Deigmatolhpsia 100000 eggrafwn kai CSV file creation

# %%
us_accidents_dts = us_accidents_OG_dataset.sample(n = 100000)

us_accidents_dts.to_csv('final_dataset.csv')
